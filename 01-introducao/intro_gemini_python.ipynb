# %% [markdown]
# Introdução a VertexAI.
#
# Material de apoio: https://github.com/lucianommartins/generative-ai-ptbr

# %% [markdown]
# ### Instale a SDK da Vertex AI

# %%
! pip3 install --upgrade google-cloud-aiplatform
! pip3 install pillow
# Out:
# Requirement already satisfied: google-cloud-aiplatform in /Users/adalto.picotti/.pyenv/versions/3.12.2/envs/vertex-ai-env/lib/python3.12/site-packages (1.43.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1 in /Users/adalto.picotti/.pyenv/versions/3.12.2/envs/vertex-ai-env/lib/python3.12/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform) (2.17.1)
# Requirement already satisfied: google-auth<3.0.0dev,>=2.14.1 in /Users/adalto.picotti/.pyenv/versions/3.12.2/envs/vertex-ai-env/lib/python3.12/site-packages (from google-cloud-aiplatform) (2.28.2)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.0 in /Users/adalto.picotti/.pyenv/versions/3.12.2/envs/vertex-ai-env/lib/python3.12/site-packages (from google-cloud-aiplatform) (1.23.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5 in /Users/adalto.picotti/.pyenv/versions/3.12.2/envs/vertex-ai-env/lib/python3.12/site-packages (from google-cloud-aiplatform) (4.25.3)
# Requirement already satisfied: packaging>=14.3 in /Users/adalto.picotti/.pyenv/versions/3.12.2/envs/vertex-ai-env/lib/python3.12/site-packages (from google-cloud-aiplatform) (23.2)
# Requirement already satisfied: google-cloud-storage<3.0.0dev,>=1.32.0 in /Users/adalto.picotti/.pyenv/versions/3.12.2/envs/vertex-ai-env/lib/python3.12/site-packages (from google-cloud-aiplatform) (2.15.0)
# Requirement already satisfied: google-cloud-bigquery<4.0.0dev,>=1.15.0 in /Users/adalto.picotti/.pyenv/versions/3.12.2/envs/vertex-ai-env/lib/python3.12/site-packages (from google-cloud-aiplatform) (3.18.0)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0dev,>=1.3.3 in /Users/adalto.picotti/.pyenv/versions/3.12.2/envs/vertex-ai-env/lib/python3.12/site-packages (from google-cloud-aiplatform) (1.12.3)
# Requirement already satisfied: shapely<3.0.0dev in /Users/adalto.picotti/.pyenv/versions/3.12.2/envs/vertex-ai-env/lib/python3.12/site-packages (from google-cloud-aiplatform) (2.0.3)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /Users/adalto.picotti/.pyenv/versions/3.12.2/envs/vertex-ai-env/lib/python3.12/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform) (1.62.0)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in /Users/adalto.picotti/.pyenv/versions/3.12.2/envs/vertex-ai-env/lib/python3.12/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform) (2.31.0)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /Users/adalto.picotti/.pyenv/versions/3.12.2/envs/vertex-ai-env/lib/python3.12/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform) (1.62.1)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /Users/adalto.picotti/.pyenv/versions/3.12.2/envs/vertex-ai-env/lib/python3.12/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform) (1.62.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/adalto.picotti/.pyenv/versions/3.12.2/envs/vertex-ai-env/lib/python3.12/site-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/adalto.picotti/.pyenv/versions/3.12.2/envs/vertex-ai-env/lib/python3.12/site-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/adalto.picotti/.pyenv/versions/3.12.2/envs/vertex-ai-env/lib/python3.12/site-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform) (4.9)
# Requirement already satisfied: google-cloud-core<3.0.0dev,>=1.6.0 in /Users/adalto.picotti/.pyenv/versions/3.12.2/envs/vertex-ai-env/lib/python3.12/site-packages (from google-cloud-bigquery<4.0.0dev,>=1.15.0->google-cloud-aiplatform) (2.4.1)
# Requirement already satisfied: google-resumable-media<3.0dev,>=0.6.0 in /Users/adalto.picotti/.pyenv/versions/3.12.2/envs/vertex-ai-env/lib/python3.12/site-packages (from google-cloud-bigquery<4.0.0dev,>=1.15.0->google-cloud-aiplatform) (2.7.0)
# Requirement already satisfied: python-dateutil<3.0dev,>=2.7.2 in /Users/adalto.picotti/.pyenv/versions/3.12.2/envs/vertex-ai-env/lib/python3.12/site-packages (from google-cloud-bigquery<4.0.0dev,>=1.15.0->google-cloud-aiplatform) (2.9.0.post0)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0dev,>=0.12.4 in /Users/adalto.picotti/.pyenv/versions/3.12.2/envs/vertex-ai-env/lib/python3.12/site-packages (from google-cloud-resource-manager<3.0.0dev,>=1.3.3->google-cloud-aiplatform) (0.13.0)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /Users/adalto.picotti/.pyenv/versions/3.12.2/envs/vertex-ai-env/lib/python3.12/site-packages (from google-cloud-storage<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (1.5.0)
# Requirement already satisfied: numpy<2,>=1.14 in /Users/adalto.picotti/.pyenv/versions/3.12.2/envs/vertex-ai-env/lib/python3.12/site-packages (from shapely<3.0.0dev->google-cloud-aiplatform) (1.26.4)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /Users/adalto.picotti/.pyenv/versions/3.12.2/envs/vertex-ai-env/lib/python3.12/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform) (0.5.1)
# Requirement already satisfied: six>=1.5 in /Users/adalto.picotti/.pyenv/versions/3.12.2/envs/vertex-ai-env/lib/python3.12/site-packages (from python-dateutil<3.0dev,>=2.7.2->google-cloud-bigquery<4.0.0dev,>=1.15.0->google-cloud-aiplatform) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/adalto.picotti/.pyenv/versions/3.12.2/envs/vertex-ai-env/lib/python3.12/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/adalto.picotti/.pyenv/versions/3.12.2/envs/vertex-ai-env/lib/python3.12/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/adalto.picotti/.pyenv/versions/3.12.2/envs/vertex-ai-env/lib/python3.12/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/adalto.picotti/.pyenv/versions/3.12.2/envs/vertex-ai-env/lib/python3.12/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform) (2024.2.2)
# Requirement already satisfied: pillow in /Users/adalto.picotti/.pyenv/versions/3.12.2/envs/vertex-ai-env/lib/python3.12/site-packages (10.2.0)

# %% [markdown]
# ### Reinicie o kernel do jupyter notebbok
# Como a instalação está sendo realizada com a opção `--user` é necessário reiniciar o kernel para que os novos módulos se tornem acessíveis.

# %%
import IPython

app = IPython.Application.instance()
app.kernel.do_shutdown(True)
# Out:
# {'status': 'ok', 'restart': True}
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ### Import as bibliotecas necessárias

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

import warnings
warnings.simplefilter("ignore", UserWarning)

from vertexai.generative_models import (
    GenerationConfig,
    GenerativeModel,
    Image,
    Part,
)

import vertexai

# %% [markdown]
# ### Import o modelo Gemini 1.0 pro
#
# O Gemini Pro (`gemini-1.0-pro`) ajuda na realização de tarefas utilizando linguagem natural, chats multiturno de texto e código e para a geração de código.

# %%
model = GenerativeModel("gemini-1.0-pro")

# %% [markdown]
# ### Gere textos a partir de prompts de texto
#
# Envie um prompt de texto para o modelo. O modelo Gemini Pro (`gemini-pro`) fornece um mecanismo de resposta de streaming. Com esta abordagem, você não precisa esperar pela resposta completa; você pode começar a processar fragmentos assim que estiverem acessíveis.

# %%
responses = model.generate_content("Por que o céu é azul?", stream=True)

for response in responses:
    print(response.text, end="")
# Out:
# O céu é azul devido ao fenômeno conhecido como dispersão de Rayleigh.
#
# Quando a luz solar atinge a atmosfera da Terra, ela interage com moléculas de nitrogênio e oxigênio, que são muito menores que o comprimento de onda da luz visível.
#
# Essas interações fazem com que a luz seja desviada em todas as direções. Entretanto, a luz azul de comprimento de onda mais curto é espalhada com maior eficiência do que outras cores.
#
# Como resultado, a luz espalhada que chega aos nossos olhos é predominantemente azul, fazendo com que o céu pareça azul durante o dia.
#
# Ao pôr do sol e ao nascer do sol, quando a luz solar tem que viajar através de uma maior quantidade da atmosfera para nos alcançar, mais luz azul é espalhada. Isso faz com que o céu tenha uma cor avermelhada ou laranja.

# %%
responses = model.generate_content("Por que o céu é roxo?", stream=True)

for response in responses:
    print(response.text, end="")
# Out:
# O céu geralmente não é roxo. Durante o amanhecer e o pôr do sol, ele pode assumir tons avermelhados, alaranjados ou roxos devido ao espalhamento da luz do sol por partículas na atmosfera da Terra.

# %% [markdown]
# **Experimente seus próprios prompts**
# - Quais são os maiores desafios que o setor de saúde enfrenta?
# - Quais são os ultimos desenvolvimentos na industria automotiva?

# %%
prompt = """Crie uma lista numerada de 10 itens. Cada item da lista deve ser uma tendência na industria de games.
Cada tendência deve ter menos de 5 palavras"""

responses = model.generate_content(prompt, stream=True)

for response in responses:
    print(response.text, end="")
# Out:
# 1. Jogos como serviço
# 2. Realidade virtual e aumentada
# 3. Jogos móveis casuais
# 4. E-sports
# 5. Streaming ao vivo
# 6. Inteligência artificial
# 7. Jogos multiplataforma
# 8. Jogos na nuvem
# 9. Jogos sociais multijogador
# 10. Jogos independentes

# %% [markdown]
# **Parâmetro do modelo**
#
# Cada prompt enviado ao modelo inclui alores de parâmetros que controlam como o modelo gera uma resposta. O modelo pode gerar resultados diferentes para valores de parâmetros difernetes. Você pode experimentar diferentes parâmetros do modelo para ve como os resultados mudam.

# %%
generation_config = GenerationConfig(
    temperature=0.9, # Controla a aletorieadade da previsão
    top_p=1.0,
    top_k=32,
    candidate_count=1,
    max_output_tokens=100, # tamanho das respostas (entre 1 e 8192 para o Gemini-Pro)
)

responses = model.generate_content(
    "Por que o Céu é azul?",
    generation_config=generation_config,
    stream=True
)

for response in responses:
    print(response.text, end="")
# Out:
# O céu parece azul devido a um fenômeno físico chamado dispersão de Rayleigh.
#
# **Dispersão de Rayleigh**
#
# A luz branca do sol é composta por várias cores, cada uma com seu próprio comprimento de onda. Quando a luz branca passa pela atmosfera da Terra, as moléculas de nitrogênio e oxigênio interagem com os fótons de luz. Essas moléculas são muito menores do que os comprimentos de onda da luz.
#
# A dispersão de Rayleigh é um tipo de

# %% [markdown]
# **Teste os prompts de chat**
#
# O modelo Gemini Pro oferece suporte a chats com vários turnos e é ideal para tarefas de texto que exigem interações de ida e volta. Os exemplos a seguir mostram como o modelo responde durante uma conversa multiturnos.

# %%
chat = model.start_chat()

prompt = """Você é um operador de uma empresa de Gestão financeira completa para instituições de ensino superior.
Simule uma cobrança de uma mensalidade vencida para o aluno Jonh Doe, e tente convence-lo de forma amigavel a realizar o pagamento ou negociar sua divida.
"""

responses = chat.send_message(prompt, stream=True)

for response in responses:
    print(response.text, end="")
# Out:
# **Assunto: Mensalidade Vencida - Jonh Doe**
#
# Caro Jonh,
#
# Esperamos que este e-mail o encontre bem.
#
# Estamos entrando em contato para informá-lo sobre sua mensalidade vencida referente ao mês de [mês]. O valor total devido é de R$ [valor da mensalidade].
#
# Entendemos que imprevistos financeiros podem acontecer. Se você estiver passando por quaisquer dificuldades, estamos dispostos a trabalhar com você para encontrar uma solução. Podemos oferecer planos de pagamento flexíveis que se ajustem ao seu orçamento atual.
#
# Além disso, estamos oferecendo um desconto de [porcentagem]% se o pagamento for realizado até [data]. Este desconto visa ajudá-lo a quitar sua dívida de forma mais rápida e conveniente.
#
# Sabemos que a educação é valiosa e queremos garantir que você continue a ter acesso às oportunidades que nossa instituição tem a oferecer. O pagamento pontual das mensalidades é essencial para manter sua matrícula e evitar penalidades futuras.
#
# Caso você tenha alguma dúvida ou precise de assistência para realizar o pagamento ou negociar sua dívida, não hesite em entrar em contato com nossa equipe pelo e-mail [endereço de e-mail]. Estaremos disponíveis para ajudá-lo durante o horário comercial.
#
# Obrigado por sua atenção imediata a este assunto.
#
# Atenciosamente,
# Equipe de Gestão Financeira
# [Nome da instituição de ensino superior]

# %% [markdown]
# Este prompt de acompanhamento mostra como o modelo responde com base no prompt anterior:

# %%
prompt = "Não sei do que se trata essa mensalidade."

responses = chat.send_message(prompt, stream=True)

for response in responses:
    print(response.text, end="")
# Out:
# Caro Jonh,
#
# Obrigado por entrar em contato conosco.
#
# Entendemos que você pode não estar ciente da mensalidade vencida referente ao mês de [mês]. Isso pode ocorrer por vários motivos, como:
#
# * Erro na emissão da fatura
# * Atraso no envio da fatura
# * Falta de recebimento da fatura
#
# Para esclarecer a situação, solicitamos que você verifique os seguintes itens:
#
# * Sua conta de e-mail (incluindo a caixa de spam) para localizar a fatura
# * Entre em contato com o departamento financeiro da sua instituição para confirmar o valor devido
# * Verifique se houve algum erro no registro do seu endereço ou informações de contato
#
# Se você confirmar que não recebeu a fatura ou que houve um erro, entre em contato conosco imediatamente para que possamos corrigir a situação.
#
# Estamos dispostos a trabalhar com você para encontrar uma solução que funcione para ambas as partes. Entre em contato conosco pelo e-mail [endereço de e-mail] ou pelo telefone [número de telefone] para discutir suas opções.
#
# Agradecemos sua compreensão e cooperação.
#
# Atenciosamente,
# Equipe de Gestão Financeira
# [Nome da instituição de ensino superior]

# %% [markdown]
# Você também pode ter acesso ao histórico do chat:

# %%
print(chat.history)
# Out:
# [role: "user"
# parts {
#   text: "Você é um operador de uma empresa de Gestão financeira completa para instituições de ensino superior.\nSimule uma cobrança de uma mensalidade vencida para o aluno Jonh Doe, e tente convence-lo de forma amigavel a realizar o pagamento ou negociar sua divida.\n"
# }
# , role: "model"
# parts {
#   text: "**Assunto: Mensalidade Vencida - Jonh Doe**\n\nCaro Jonh,\n\nEsperamos que este e-mail o encontre bem.\n\nEstamos entrando em contato para informá-lo sobre sua mensalidade vencida referente ao mês de [mês]. O valor total devido é de R$ [valor da mensalidade].\n\nEntendemos que imprevistos financeiros podem acontecer. Se você estiver passando por quaisquer dificuldades, estamos dispostos a trabalhar com você para encontrar uma solução. Podemos oferecer planos de pagamento flexíveis que se ajustem ao seu orçamento atual.\n\nAlém disso, estamos oferecendo um desconto de [porcentagem]% se o pagamento for realizado até [data]. Este desconto visa ajudá-lo a quitar sua dívida de forma mais rápida e conveniente.\n\nSabemos que a educação é valiosa e queremos garantir que você continue a ter acesso às oportunidades que nossa instituição tem a oferecer. O pagamento pontual das mensalidades é essencial para manter sua matrícula e evitar penalidades futuras.\n\nCaso você tenha alguma dúvida ou precise de assistência para realizar o pagamento ou negociar sua dívida, não hesite em entrar em contato com nossa equipe pelo e-mail [endereço de e-mail]. Estaremos disponíveis para ajudá-lo durante o horário comercial.\n\nObrigado por sua atenção imediata a este assunto.\n\nAtenciosamente,\nEquipe de Gestão Financeira\n[Nome da instituição de ensino superior]"
# }
# , role: "user"
# parts {
#   text: "Não sei do que se trata essa mensalidade."
# }
# , role: "model"
# parts {
#   text: "Caro Jonh,\n\nObrigado por entrar em contato conosco.\n\nEntendemos que você pode não estar ciente da mensalidade vencida referente ao mês de [mês]. Isso pode ocorrer por vários motivos, como:\n\n* Erro na emissão da fatura\n* Atraso no envio da fatura\n* Falta de recebimento da fatura\n\nPara esclarecer a situação, solicitamos que você verifique os seguintes itens:\n\n* Sua conta de e-mail (incluindo a caixa de spam) para localizar a fatura\n* Entre em contato com o departamento financeiro da sua instituição para confirmar o valor devido\n* Verifique se houve algum erro no registro do seu endereço ou informações de contato\n\nSe você confirmar que não recebeu a fatura ou que houve um erro, entre em contato conosco imediatamente para que possamos corrigir a situação.\n\nEstamos dispostos a trabalhar com você para encontrar uma solução que funcione para ambas as partes. Entre em contato conosco pelo e-mail [endereço de e-mail] ou pelo telefone [número de telefone] para discutir suas opções.\n\nAgradecemos sua compreensão e cooperação.\n\nAtenciosamente,\nEquipe de Gestão Financeira\n[Nome da instituição de ensino superior]"
# }
# ]

# %% [markdown]
# ## Gemini 1.0 Pro Vision
#
# ### Importe o modelo Gemini 1.0 Pro Vision
#
# Gemini Pro Vision (`gemini-pro-vision`) é um modelo multimodal que suporta prompts multimodais.
# Você pode incluir texto, imagem(s) e vídeo em suas solicitações de prompt e obter respostas em texto ou códigpo.

# %%
multimodal_model = GenerativeModel('gemini-1.0-pro-vision')

# %% [markdown]
# Defina funções auxiliares para carregar e exibir imagens.

# %%
import http.client
import typing
import urllib.request

import IPython.display
from PIL import Image as PIL_Image
from PIL import ImageOps as PIL_ImageOps

def display_images(
        images: typing.Iterable[Image],
        max_width: int = 600,
        max_height: int = 300,
) -> None:
    for image in images:
        pil_image = typing.cast(PIL_Image.Image, image._pil_image)
        if pil_image.mode != "RGB":
            # RGB is supported by all jupyter environments
            pil_image = pil_image.convert("RGB")
        image_width , image_height = pil_image.size
        if max_width < image_width or max_height < image_height:
            # Resize to display a smaller notebook image
            pil_image = PIL_ImageOps.contain(pil_image, (max_width, max_height))
        IPython.display.display(pil_image)

def get_image_bytes_from_url(image_url: str) -> bytes:
    with urllib.request.urlopen(image_url) as response:
        response = typing.cast(http.client.HTTPResponse, response)
        image_bytes = response.read()
    return image_bytes

def load_image_from_url(image_url: str) -> Image:
    image_bytes = get_image_bytes_from_url(image_url)
    return Image.from_bytes(image_bytes)

def get_url_from_gcs(gcs_uri: str) -> str:
    # convertes gcs uri to url for image display.
    url = "https://storage.googleapis.com/" + gcs_uri.replace("gs://", "").replace(" ", "%20")
    return url

def print_multimodal_prompt(contents: list):
    for content in contents:
        if isinstance(content, Image):
            display_images([content])
        elif isinstance(content, Part):
            url = get_url_from_gcs(content.file_data.file_uri)
            IPython.display.display(load_image_from_url(url))
        else: 
            print(content)

# %% [markdown]
# ### Gere texto a partir de imagens locais
#
# Use o método `Image.load_from_file` para carregar um arquivo local como a imagem para a qual gerar o texto.

# %%
# ! gsutil cp "gs://cloud-samples-data/generative-ai/image/320px-Felis_catus-cat_on_snow.jpg" ./image.jpg

# Load from local file
image = Image.load_from_file("image.jpg")

# Prepare contents
prompt = "Descreva esta imagem (quebre em topicos)"
contents = [image, prompt]

responses = multimodal_model.generate_content(contents, stream=True)

print("----------- Prompt -----------")
print_multimodal_prompt(contents)

print("----------- Resposta -----------")
for response in responses:
    print(response.text, end="")
# Out:
# ----------- Prompt -----------
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x213>
# Descreva esta imagem (quebre em topicos)
# ----------- Resposta -----------
#  * Um gato marrom listrado está andando na neve.
# * O gato tem uma expressão séria no rosto.
# * O gato está com a cauda levantada.
# * As patas do gato estão afundando na neve.
# * O fundo da imagem é uma floresta coberta de neve.

# %% [markdown]
# ### Gere texto a partir de texto e imagens
# **Imagens com URIs do Cloud Storage**
#
# Se suas imagens estiverem armazenadas no Cloud Storage, você poderá especificar o URI do Cloud Storage da imagem para incluir no prompt. Você também deve especificar o campo `mime_type`. Os tipos MIME suportados para imagens incluem `image/png` e `image/jpeg`.
#
# Observe que o URI (não deve ser confundido com URL) de um objeto do Cloud Storage deve sempre começar com `gs://`.

# %%
# Load image from Cloud Storage URI
gcs_uri = "gs://cloud-samples-data/generative-ai/image/boats.jpeg"

# Prepare contents
image = Part.from_uri(gcs_uri, mime_type="image/jpeg")
prompt = "Descreva esta cena"
contents = [image, prompt]

responses = multimodal_model.generate_content(contents, generation_config=GenerationConfig(temperature=0.0), stream=True)

print("-------Prompt--------")
print_multimodal_prompt(contents)

print("\n-------Resposta--------")
for response in responses:
    print(response.text, end="")
# Out:
# -------Prompt--------
# Descreva esta cena
#
# -------Resposta--------
#  Esta imagem mostra um barco ancorado em um rio. Ao fundo, há uma ponte e prédios altos. O dia está nublado.

# %% [markdown]
# ### Imagens com links diretos
#
# Você também pode usar links diretos para imagens, conforme mostrado abaixo. A função auxiliar `load_image_from_url()` (que foi declarada anteriormente) converte a imagem em bytes e a retorna como um objeto Image que pode ser enviado ao `Gemini Pro Vision` junto com o prompt de texto.

# %%
# Load image from Cloud Storage URI
image_url = (
    "https://storage.googleapis.com/cloud-samples-data/generative-ai/image/boats.jpeg"
)
image = load_image_from_url(image_url) # convert to bytes

# Prepare contents
prompt = "Descreva esta cena"
contents = [image, prompt]

responses = multimodal_model.generate_content(contents, generation_config=GenerationConfig(temperature=0.0), stream=True)

print("-------Prompt--------")
print_multimodal_prompt(contents)

print("\n-------Resposta--------")
for response in responses:
    print(response.text, end="")
# Out:
# -------Prompt--------
# <PIL.Image.Image image mode=RGB size=400x300>
# Descreva esta cena
#
# -------Resposta--------
#  Esta imagem mostra um barco ancorado em um rio. Ao fundo, há uma ponte e prédios altos. O dia está nublado.

# %% [markdown]
# ### Combinando várias imagens e solicitações de texto em um prompt few-shot
# Você pode enviar mais de uma imagem por vez e também colocá-las em qualquer lugar ao lado do prompt de texto.
#
# No exemplo abaixo, a solicitação de poucas fotos é executada para que o `Gemini Pro Vision` retorne a cidade e o ponto de referência em um formato JSON específico.

# %%
# Load images from Cloud Storage URI
image1_url = "https://storage.googleapis.com/github-repo/img/gemini/intro/landmark1.jpg"
image2_url = "https://storage.googleapis.com/github-repo/img/gemini/intro/landmark2.jpg"
image3_url = "https://storage.googleapis.com/github-repo/img/gemini/intro/landmark3.jpg"
image1 = load_image_from_url(image1_url)
image2 = load_image_from_url(image2_url)
image3 = load_image_from_url(image3_url)

# Prepare prompts
prompt1 = """{"cidade": "Londres", "ponto_turistico:", "Big Ben"}"""
prompt2 = """{"cidade": "Paris", "ponto_turistico:", "Torre Eiffel"}"""

# Prepare contents
contents = [image1, prompt1, image2, prompt2, image3]

responses = multimodal_model.generate_content(contents, stream=True)

print("-------Prompt--------")
print_multimodal_prompt(contents)

print("\n-------Resposta--------")
for response in responses:
    print(response.text, end="")
# Out:
# -------Prompt--------
# <PIL.Image.Image image mode=RGB size=450x300>
# {"cidade": "Londres", "ponto_turistico:", "Big Ben"}
# <PIL.Image.Image image mode=RGB size=450x300>
# {"cidade": "Paris", "ponto_turistico:", "Torre Eiffel"}
# <PIL.Image.Image image mode=RGB size=411x300>
# -------Resposta--------
#  {"cidade": "Roma", "ponto_turistico:", "Coliseu"}

# %% [markdown]
# ### Gere texto a partir de um arquivo de vídeo
#
# Especifique o URI do Cloud Storage de um vídeo a ser incluído no prompt. Você também deve especificar o campo `mime_type`. O tipo MIME suportado para vídeo inclui `video/mp4`.

# %%
file_path = "github-repo/img/gemini/multimodality_usecases_overview/pixel8.mp4"
video_uri = f"gs://{file_path}"
video_url = f"https://storage.googleapis.com/{file_path}"

IPython.display.Video(video_url, width=450)
# Out:
# <video src="https://storage.googleapis.com/github-repo/img/gemini/multimodality_usecases_overview/pixel8.mp4" controls  width="450" >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
prompt = """
Responda às seguintes perguntas usando apenas o vídeo:
Qual é a profissão da pessoa principal do vídeo?
Quais são as principais funcionalidades do telefone são apresentadas neste vídeo?
Em que cidade isso foi gravado?
Qual o nome da pessoa principal do vídeo?
Quantos acessórios é possível notar na pessoa principal do vídeo? Quais são eles?
Forneça a resposta JSON.
"""

video = Part.from_uri(video_uri, mime_type="video/mp4")
contents = [prompt, video]

responses = multimodal_model.generate_content(contents, stream=True)

for response in responses:
    print(response.text, end="")
# Out:
#  ```json
# {
#   "profissao": "fotógrafa",
#   "funcionalidades": "modo noturno, vídeo boost",
#   "cidade": "Tóquio",
#   "nome": "Saeka Shimada",
#   "acessorios": "bolsa, brinco, anel, blusa listrada"
# }
# ```
